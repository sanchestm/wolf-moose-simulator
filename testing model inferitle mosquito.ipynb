# %%
import random as rd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
plt.style.use("ggplot")
from math import *
import numpy as np
import pickle as pkl
import skimage as ski
from skimage.color import rgb2gray
from scipy import misc
from PIL import Image
import PIL.ImageOps
from skimage.exposure import adjust_gamma
from randomwalkmaker import *
from gridclasses import *
get_ipython().magic('matplotlib inline')

# %%
a = Cell(np.array([10, 10, 10, 10, 10, 10]),1,1,1,0, 100, 1000000, 0 )
lista = []
for i in range(150): a.update(); lista += [a.n_adult]
a.pmut = 5000#; a.amut = 5000; a.emut = 5000; 
for i in range(500): a.update(); lista += [a.n_adult]
plt.plot(range(len(lista)), lista)
plt.show()
